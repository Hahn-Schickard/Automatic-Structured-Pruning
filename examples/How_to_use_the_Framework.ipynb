# %% [markdown]
# # Pruning with our automatic structured Pruning framework
# Welcome to an end-to-end example for magnitude-based weight pruning
#
# **Summary**
#
# In this tutorial, you will:
#
# * Train a tf.keras model for CIFAR10 from scratch.
# * Fine tune the model by applying the pruning Framework and see the accuracy.

# %% [markdown]
# If you want to execute this notebook in Google Colab, uncomment the code below.

# %%
import sys

if 'google.colab' in sys.modules:
    # !git clone https://github.com/Hahn-Schickard/Automatic-Structured-Pruning
    # !echo $CWD
    sys.path.append("Automatic-Structured-Pruning/src")
else:
    sys.path.append("../src")
    
import pruning

# %% [markdown]
# ## Train a model for CIFAR10 without pruning
# Download and prepare the CIFAR10 dataset.
# The CIFAR10 dataset contains 60,000 color images in 10 classes, with 6,000 images in each class. The dataset is divided into 50,000 training images and 10,000 testing images. The classes are mutually exclusive and there is no overlap between them.
#
# Create the convolutional base
# The 6 lines of code below define the convolutional base using a common pattern: a stack of Conv2D and MaxPooling2D layers.
#
# As input, a CNN takes tensors of shape (image_height, image_width, color_channels), ignoring the batch size. If you are new to these dimensions, color_channels refers to (R,G,B). In this example, you will configure our CNN to process inputs of shape (32, 32, 3), which is the format of CIFAR images. You can do this by passing the argument input_shape to our first layer.
#
# To complete our model, you will feed the last output tensor from the convolutional base (of shape (4, 4, 64)) into one or more Dense layers to perform classification. Dense layers take vectors as input (which are 1D), while the current output is a 3D tensor. First, you will flatten (or unroll) the 3D output to 1D, then add one or more Dense layers on top. CIFAR has 10 output classes, so you use a final Dense layer with 10 outputs and a softmax activation.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models


(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Above, you can see that the output of every Conv2D and MaxPooling2D layer is a 3D tensor of shape (height, width, channels). The width and height dimensions tend to shrink as you go deeper in the network. The number of output channels for each Conv2D layer is controlled by the first argument (e.g., 32 or 64). Typically, as the width and height shrink, you can afford (computationally) to add more output channels in each Conv2D layer.
# As you can see, our (4, 4, 64) outputs were flattened into vectors of shape (1024) before going through two Dense layers.

# %% [markdown]
# ## Compile and train the model

# %%
comp = {
"optimizer":'adam',
"loss": tf.keras.losses.SparseCategoricalCrossentropy(),
"metrics": ['accuracy']}

model.compile(**comp)
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]

model.fit(train_images, train_labels, validation_split=0.2, epochs=1, batch_size=128, callbacks=callbacks)

model_test_loss, model_test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f"Model accuracy after Training: {model_test_acc*100:.2f}%")
# Out:
# 313/313 [==============================] - 5s 8ms/step - loss: 1.9597 - accuracy: 0.2556 - val_loss: 1.6243 - val_accuracy: 0.4015
# 313/313 - 1s - loss: 1.6066 - accuracy: 0.4124
# Model accuracy after Training: 41.24%

# %% [markdown]
# ## Fine-tune pre-trained model with pruning
# You will apply pruning to the whole model and see this in the model summary.
#
# In this example, you prune the model with 30% dense pruning and 40% filter pruning.

# %%
import asp as pruning

# %%
dir(pruning)
# Out:
# ['Model',
#  'NamedTuple',
#  'NetStructure',
#  'Sequential',
#  'ThresholdCallback',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'accuracy_pruning',
#  'build_pruned_model',
#  'copy',
#  'delete_dense_neuron',
#  'delete_filter',
#  'factor_pruning',
#  'get_filter_to_prune_avarage',
#  'get_filter_to_prune_l2',
#  'get_last_layer_with_params',
#  'get_layer_shape_conv',
#  'get_layer_shape_dense',
#  'get_neurons_to_prune_l1',
#  'get_neurons_to_prune_l2',
#  'load_model',
#  'load_model_param',
#  'model_pruning',
#  'np',
#  'os',
#  'prun_filters_conv',
#  'prun_neurons_dense',
#  'pruning',
#  'pruning_helper_classes',
#  'pruning_helper_functions',
#  'pruning_helper_functions_conv',
#  'pruning_helper_functions_dense',
#  'stepwise_accuracy_pruning',
#  'stepwise_factor_pruning',
#  'tf',
#  'train_test_split']

# %%
dense_prune_rate=40
conv_prune_rate=40
pruned_model=pruning.factor_pruning(model, dense_prune_rate, conv_prune_rate,'L1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\dk100\Documents\Automatic-Structured-Pruning\examples\How_to_use_the_Framework.ipynb Cell 11 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dk100/Documents/Automatic-Structured-Pruning/examples/How_to_use_the_Framework.ipynb#ch0000009?line=0'>1</a> dense_prune_rate=40
#       <a href='vscode-notebook-cell:/c%3A/Users/dk100/Documents/Automatic-Structured-Pruning/examples/How_to_use_the_Framework.ipynb#ch0000009?line=1'>2</a> conv_prune_rate=40
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dk100/Documents/Automatic-Structured-Pruning/examples/How_to_use_the_Framework.ipynb#ch0000009?line=2'>3</a> pruned_model=pruning.factor_pruning(model, dense_prune_rate, conv_prune_rate,'L1')
#
# File c:\Users\dk100\Anaconda3\envs\AutoFlow\lib\site-packages\asp\pruning.py:63, in factor_pruning(keras_model, prun_factor_dense, prun_factor_conv, metric, comp, label_one_hot)
#      56     else:
#      57         comp = {
#      58             "optimizer": 'adam',
#      59             "loss": tf.keras.losses.SparseCategoricalCrossentropy(),
#      60             "metrics": 'accuracy'}
#      62 layer_types, layer_params, layer_output_shape, layer_bias, netstr = (
# ---> 63     load_model_param(model))
#      64 num_new_neurons = np.zeros(shape=len(layer_params), dtype=np.int16)
#      65 num_new_filters = np.zeros(shape=len(layer_params), dtype=np.int16)
#
# NameError: name 'load_model_param' is not defined

# %% [markdown]
# We see how we get less parameter in the pruned model.

# %% [markdown]
# ## Compile and re-train the model

# %%
pruned_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 20)        560
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 20)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 39)        7059
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 39)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 39)          13728
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 39)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 156)               0
# _________________________________________________________________
# dense (Dense)                (None, 39)                6123
# _________________________________________________________________
# dropout (Dropout)            (None, 39)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# =================================================================
# Total params: 28,480
# Trainable params: 28,480
# Non-trainable params: 0
# _________________________________________________________________

# %%
comp = {
"optimizer":'adam',
"loss": tf.keras.losses.SparseCategoricalCrossentropy(),
"metrics": ['accuracy']}

pruned_model.compile(**comp)

pruned_model.fit(train_images, train_labels, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4542 - accuracy: 0.4861 - val_loss: 1.0916 - val_accuracy: 0.6137
# Epoch 2/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1882 - accuracy: 0.5921 - val_loss: 1.0641 - val_accuracy: 0.6320
# Epoch 3/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1052 - accuracy: 0.6205 - val_loss: 1.0003 - val_accuracy: 0.6511
# Epoch 4/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0643 - accuracy: 0.6380 - val_loss: 0.9920 - val_accuracy: 0.6563
# Epoch 5/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0240 - accuracy: 0.6539 - val_loss: 0.9453 - val_accuracy: 0.6737
# Epoch 6/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9967 - accuracy: 0.6642 - val_loss: 0.9414 - val_accuracy: 0.6761
# Epoch 7/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9782 - accuracy: 0.6694 - val_loss: 0.9450 - val_accuracy: 0.6764
# Epoch 8/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9507 - accuracy: 0.6807 - val_loss: 0.9779 - val_accuracy: 0.6711
# Epoch 9/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9247 - accuracy: 0.6861 - val_loss: 0.9797 - val_accuracy: 0.6700
# Epoch 10/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9099 - accuracy: 0.6913 - val_loss: 0.9310 - val_accuracy: 0.6853

# %% [markdown]
# Compare both models

# %%
model_test_loss, model_test_acc = model.evaluate(test_images,  test_labels, verbose=2)
pruned_model_test_loss, pruned_model_test_acc = pruned_model.evaluate(test_images,  test_labels, verbose=2)

print(f"Model accuracy before pruning: {model_test_acc*100:.2f}%")
print(f"Model accuracy after pruning: {pruned_model_test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - loss: 0.9143 - accuracy: 0.6925
# 313/313 - 1s - loss: 0.9476 - accuracy: 0.6848
# Model accuracy before pruning: 69.25%
# Model accuracy after pruning: 68.48%

# %%
print(f"Total number of parameters before pruning: {model.count_params()}")
print(f"Total number of parameters after pruning: {pruned_model.count_params()}")
print(f"Pruned model contains only {(pruned_model.count_params()/model.count_params())*100:.2f}% of the original number of parameters.")
# Out:
# Total number of parameters before pruning: 75178
# Total number of parameters after pruning: 28480
# Pruned model contains only 37.88% of the original number of parameters.

# %% [markdown]
# # Prune a model to a maximum accuracy loss
#
# We define the arguments to compile the model. In this case, we only want to have an accuracy loss of 3%.
# In this example we have loaded the data directly from a TensorFlow dataset. Therefore, we do not have a defined dataloader (path or file). However, the structure of the training data is the same as the data we would read from a Python file. Therefore, we use a trick here and pass an existing FILE from the current folder as the dataloader path. This way the correct functions will be executed afterwards and no error will be issued.

# %%
comp = {
  "optimizer": 'adam',
  "loss": tf.keras.losses.SparseCategoricalCrossentropy(),
  "metrics": 'accuracy'
}

auto_model = pruning.accuracy_pruning(model, comp, train_images, train_labels, test_images,
                                     test_labels, pruning_acc=None, max_acc_loss=3,
                                     label_one_hot=False)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9143 - accuracy: 0.6925
# Start model accuracy: 69.25 %
# Minimum required model accuracy: 66.25 %
# Next pruning factors: 5
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 31)        868
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 31)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 61)        17080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 61)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 61)          33550
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 61)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 244)               0
# _________________________________________________________________
# dense (Dense)                (None, 61)                14945
# _________________________________________________________________
# dropout (Dropout)            (None, 61)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 31)                1922
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                320
# =================================================================
# Total params: 68,685
# Trainable params: 68,685
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.2760 - accuracy: 0.5545 - val_loss: 1.0454 - val_accuracy: 0.6355
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0114 - accuracy: 0.6570 - val_loss: 1.1655 - val_accuracy: 0.6047
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.9371 - accuracy: 0.6855 - val_loss: 0.9055 - val_accuracy: 0.6910
# Next pruning factors: 20
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 26)        728
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 26)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 52)        12220
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 52)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 52)          24388
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 52)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 208)               0
# _________________________________________________________________
# dense (Dense)                (None, 52)                10868
# _________________________________________________________________
# dropout (Dropout)            (None, 52)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 26)                1378
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 26)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                270
# =================================================================
# Total params: 49,852
# Trainable params: 49,852
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
#   1/782 [..............................] - ETA: 5:20 - loss: 3.3937 - accuracy: 0.0781WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0022s vs `on_train_batch_end` time: 0.0022s). Check your callbacks.
# 782/782 [==============================] - 5s 5ms/step - loss: 1.3306 - accuracy: 0.5298 - val_loss: 1.0369 - val_accuracy: 0.6384
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0577 - accuracy: 0.6405 - val_loss: 0.9394 - val_accuracy: 0.6760
# Next pruning factors: 35
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 42)        7980
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 42)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 42)          15918
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 42)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 168)               0
# _________________________________________________________________
# dense (Dense)                (None, 42)                7098
# _________________________________________________________________
# dropout (Dropout)            (None, 42)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                903
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 32,707
# Trainable params: 32,707
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.4476 - accuracy: 0.4898 - val_loss: 1.1080 - val_accuracy: 0.6042
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1444 - accuracy: 0.6103 - val_loss: 1.0710 - val_accuracy: 0.6353
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0685 - accuracy: 0.6338 - val_loss: 0.9821 - val_accuracy: 0.6621
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0165 - accuracy: 0.6555 - val_loss: 0.9905 - val_accuracy: 0.6560
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.9781 - accuracy: 0.6707 - val_loss: 0.9643 - val_accuracy: 0.6675
# Next pruning factors: 45
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 18)        504
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 18)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        5868
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 18)                666
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                190
# =================================================================
# Total params: 24,148
# Trainable params: 24,148
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.5845 - accuracy: 0.4376 - val_loss: 1.1508 - val_accuracy: 0.5976
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2472 - accuracy: 0.5709 - val_loss: 1.0462 - val_accuracy: 0.6357
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1589 - accuracy: 0.6055 - val_loss: 1.0222 - val_accuracy: 0.6450
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1069 - accuracy: 0.6263 - val_loss: 0.9804 - val_accuracy: 0.6640
# Next pruning factors: 55
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 29)        3944
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 29)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 29)          7598
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 29)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 116)               0
# _________________________________________________________________
# dense (Dense)                (None, 29)                3393
# _________________________________________________________________
# dropout (Dropout)            (None, 29)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                450
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 15,965
# Trainable params: 15,965
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.7614 - accuracy: 0.3755 - val_loss: 1.3193 - val_accuracy: 0.5296
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4089 - accuracy: 0.5052 - val_loss: 1.1797 - val_accuracy: 0.5857
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3146 - accuracy: 0.5406 - val_loss: 1.1286 - val_accuracy: 0.6032
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2620 - accuracy: 0.5621 - val_loss: 1.1230 - val_accuracy: 0.6030
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2259 - accuracy: 0.5787 - val_loss: 1.0735 - val_accuracy: 0.6236
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1931 - accuracy: 0.5903 - val_loss: 1.0531 - val_accuracy: 0.6335
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1689 - accuracy: 0.5967 - val_loss: 1.0292 - val_accuracy: 0.6444
# Epoch 8/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1487 - accuracy: 0.6078 - val_loss: 1.0342 - val_accuracy: 0.6403
# Epoch 9/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1302 - accuracy: 0.6140 - val_loss: 1.0140 - val_accuracy: 0.6453
# Epoch 10/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1150 - accuracy: 0.6210 - val_loss: 0.9987 - val_accuracy: 0.6527
# Next pruning factors: 50
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 32)          9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 19,162
# Trainable params: 19,162
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.6812 - accuracy: 0.4031 - val_loss: 1.2481 - val_accuracy: 0.5688
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3350 - accuracy: 0.5348 - val_loss: 1.1072 - val_accuracy: 0.6148
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2412 - accuracy: 0.5696 - val_loss: 1.0786 - val_accuracy: 0.6341
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1845 - accuracy: 0.5941 - val_loss: 1.0141 - val_accuracy: 0.6546
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1450 - accuracy: 0.6086 - val_loss: 1.0064 - val_accuracy: 0.6608
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1102 - accuracy: 0.6239 - val_loss: 1.0197 - val_accuracy: 0.6551
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0861 - accuracy: 0.6311 - val_loss: 1.0086 - val_accuracy: 0.6538
# Epoch 8/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0658 - accuracy: 0.6385 - val_loss: 0.9971 - val_accuracy: 0.6618
# Epoch 9/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0458 - accuracy: 0.6434 - val_loss: 0.9490 - val_accuracy: 0.6765
# Next pruning factors: 52
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 31)        4495
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 31)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 31)          8680
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 31)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 124)               0
# _________________________________________________________________
# dense (Dense)                (None, 31)                3875
# _________________________________________________________________
# dropout (Dropout)            (None, 31)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 18,180
# Trainable params: 18,180
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.6696 - accuracy: 0.4016 - val_loss: 1.2579 - val_accuracy: 0.5622
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3539 - accuracy: 0.5257 - val_loss: 1.1358 - val_accuracy: 0.6095
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2648 - accuracy: 0.5604 - val_loss: 1.1183 - val_accuracy: 0.6128
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2032 - accuracy: 0.5856 - val_loss: 1.1042 - val_accuracy: 0.6180
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1668 - accuracy: 0.6011 - val_loss: 1.0488 - val_accuracy: 0.6347
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1410 - accuracy: 0.6116 - val_loss: 1.0188 - val_accuracy: 0.6480
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1080 - accuracy: 0.6242 - val_loss: 1.0238 - val_accuracy: 0.6513
# Epoch 8/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0957 - accuracy: 0.6277 - val_loss: 1.0064 - val_accuracy: 0.6609
# Epoch 9/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0686 - accuracy: 0.6382 - val_loss: 0.9854 - val_accuracy: 0.6630
# Next pruning factors: 54
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 30)        4080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 30)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 30)          8130
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 30)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 120)               0
# _________________________________________________________________
# dense (Dense)                (None, 30)                3630
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                465
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 16,885
# Trainable params: 16,885
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.7886 - accuracy: 0.3505 - val_loss: 1.3247 - val_accuracy: 0.5235
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3948 - accuracy: 0.5106 - val_loss: 1.1739 - val_accuracy: 0.5877
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2910 - accuracy: 0.5475 - val_loss: 1.1221 - val_accuracy: 0.6096
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2341 - accuracy: 0.5693 - val_loss: 1.1214 - val_accuracy: 0.6077
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2056 - accuracy: 0.5817 - val_loss: 1.0539 - val_accuracy: 0.6321
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1767 - accuracy: 0.5932 - val_loss: 1.0629 - val_accuracy: 0.6301
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1529 - accuracy: 0.6044 - val_loss: 1.0155 - val_accuracy: 0.6538
# Epoch 8/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1231 - accuracy: 0.6138 - val_loss: 1.0126 - val_accuracy: 0.6561
# Epoch 9/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1157 - accuracy: 0.6142 - val_loss: 0.9856 - val_accuracy: 0.6593
# Epoch 10/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0959 - accuracy: 0.6239 - val_loss: 1.0080 - val_accuracy: 0.6533
# Pruningfactor dense and conv: 52

# %%
auto_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 31)        4495
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 31)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 31)          8680
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 31)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 124)               0
# _________________________________________________________________
# dense (Dense)                (None, 31)                3875
# _________________________________________________________________
# dropout (Dropout)            (None, 31)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 18,180
# Trainable params: 18,180
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compare both models

# %%
model_test_loss, model_test_acc = model.evaluate(test_images,  test_labels, verbose=2)
auto_model_test_loss, auto_model_test_acc = auto_model.evaluate(test_images,  test_labels, verbose=2)

print(f"Model accuracy before pruning: {model_test_acc*100:.2f}%")
print(f"Model accuracy after pruning: {auto_model_test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - loss: 0.9143 - accuracy: 0.6925
# 313/313 - 1s - loss: 0.9854 - accuracy: 0.6630
# Model accuracy before pruning: 69.25%
# Model accuracy after pruning: 66.30%

# %%
print(f"Total number of parameters before pruning: {model.count_params()}")
print(f"Total number of parameters after pruning: {auto_model.count_params()}")
print(f"Pruned model contains only {(auto_model.count_params()/model.count_params())*100:.2f}% of the original number of parameters.")
# Out:
# Total number of parameters before pruning: 75178
# Total number of parameters after pruning: 18180
# Pruned model contains only 24.18% of the original number of parameters.

# %%
step_factor_model = pruning.stepwise_factor_pruning(model, train_images, train_labels, test_images,
                               test_labels, prun_factor_dense=10, prun_factor_conv=10,
                               num_steps=10, comp=comp)
# Out:
# pruning step: 1/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 29)        812
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 29)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15196
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1711
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                300
# =================================================================
# Total params: 61,867
# Trainable params: 61,867
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.2429 - accuracy: 0.5688 - val_loss: 1.0051 - val_accuracy: 0.6420
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0039 - accuracy: 0.6568 - val_loss: 0.8911 - val_accuracy: 0.6849
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9324 - accuracy: 0.6844 - val_loss: 0.9205 - val_accuracy: 0.6874
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8947 - accuracy: 0.6986 - val_loss: 0.8269 - val_accuracy: 0.7188
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8565 - accuracy: 0.7127 - val_loss: 0.8253 - val_accuracy: 0.7193
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8259 - accuracy: 0.7212 - val_loss: 0.8922 - val_accuracy: 0.7004
# Epoch 7/10
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7951 - accuracy: 0.7326 - val_loss: 0.8455 - val_accuracy: 0.7129
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7710 - accuracy: 0.7422 - val_loss: 0.8357 - val_accuracy: 0.7103
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7556 - accuracy: 0.7466 - val_loss: 0.8403 - val_accuracy: 0.7110
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7360 - accuracy: 0.7531 - val_loss: 0.8168 - val_accuracy: 0.7181
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8971 - accuracy: 0.7024
# pruning step: 2/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 29)        812
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 29)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15196
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1711
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                300
# =================================================================
# Total params: 61,867
# Trainable params: 61,867
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 53)        12932
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 53)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 53)          25334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 53)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 212)               0
# _________________________________________________________________
# dense (Dense)                (None, 53)                11289
# _________________________________________________________________
# dropout (Dropout)            (None, 53)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                1458
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                280
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.2951 - accuracy: 0.5450 - val_loss: 1.0074 - val_accuracy: 0.6478
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9834 - accuracy: 0.6661 - val_loss: 0.9119 - val_accuracy: 0.6803
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8918 - accuracy: 0.6977 - val_loss: 0.8795 - val_accuracy: 0.6953
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8387 - accuracy: 0.7199 - val_loss: 0.8704 - val_accuracy: 0.7025
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8011 - accuracy: 0.7326 - val_loss: 0.8512 - val_accuracy: 0.7084
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7702 - accuracy: 0.7450 - val_loss: 0.8811 - val_accuracy: 0.7037
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7416 - accuracy: 0.7518 - val_loss: 0.8333 - val_accuracy: 0.7209
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7234 - accuracy: 0.7592 - val_loss: 0.8482 - val_accuracy: 0.7188
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7020 - accuracy: 0.7675 - val_loss: 0.8704 - val_accuracy: 0.7180
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6867 - accuracy: 0.7745 - val_loss: 0.9489 - val_accuracy: 0.7053
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0127 - accuracy: 0.6882
# pruning step: 3/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 53)        12932
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 53)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 53)          25334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 53)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 212)               0
# _________________________________________________________________
# dense (Dense)                (None, 53)                11289
# _________________________________________________________________
# dropout (Dropout)            (None, 53)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                1458
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                280
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 25)        700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 25)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 48)        10848
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 48)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 48)          20784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 48)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                9264
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1225
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                260
# =================================================================
# Total params: 43,081
# Trainable params: 43,081
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.2734 - accuracy: 0.5651 - val_loss: 0.9940 - val_accuracy: 0.6582
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9691 - accuracy: 0.6761 - val_loss: 0.9169 - val_accuracy: 0.6828
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8718 - accuracy: 0.7122 - val_loss: 0.9006 - val_accuracy: 0.6972
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8212 - accuracy: 0.7278 - val_loss: 0.8995 - val_accuracy: 0.7016
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7769 - accuracy: 0.7402 - val_loss: 0.9012 - val_accuracy: 0.6979
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7501 - accuracy: 0.7526 - val_loss: 0.8878 - val_accuracy: 0.7041
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7211 - accuracy: 0.7619 - val_loss: 0.8615 - val_accuracy: 0.7156
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7034 - accuracy: 0.7678 - val_loss: 0.9052 - val_accuracy: 0.7081
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6817 - accuracy: 0.7747 - val_loss: 0.9050 - val_accuracy: 0.7104
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6737 - accuracy: 0.7804 - val_loss: 0.8911 - val_accuracy: 0.7131
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9329 - accuracy: 0.7104
# pruning step: 4/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 25)        700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 25)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 48)        10848
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 48)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 48)          20784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 48)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                9264
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1225
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                260
# =================================================================
# Total params: 43,081
# Trainable params: 43,081
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 23)        644
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 23)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 44)        9152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 44)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 44)          17468
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 44)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 176)               0
# _________________________________________________________________
# dense (Dense)                (None, 44)                7788
# _________________________________________________________________
# dropout (Dropout)            (None, 44)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                240
# =================================================================
# Total params: 36,327
# Trainable params: 36,327
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.1856 - accuracy: 0.5996 - val_loss: 0.9840 - val_accuracy: 0.6675
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9194 - accuracy: 0.6936 - val_loss: 0.9144 - val_accuracy: 0.6866
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8324 - accuracy: 0.7243 - val_loss: 0.8777 - val_accuracy: 0.7042
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7771 - accuracy: 0.7426 - val_loss: 0.8701 - val_accuracy: 0.7097
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7433 - accuracy: 0.7553 - val_loss: 0.8800 - val_accuracy: 0.7122
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7155 - accuracy: 0.7636 - val_loss: 0.8885 - val_accuracy: 0.7106
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7005 - accuracy: 0.7678 - val_loss: 0.8933 - val_accuracy: 0.7095
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6883 - accuracy: 0.7721 - val_loss: 0.9162 - val_accuracy: 0.7069
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6641 - accuracy: 0.7807 - val_loss: 0.9087 - val_accuracy: 0.7110
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6508 - accuracy: 0.7849 - val_loss: 0.9458 - val_accuracy: 0.6993
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9804 - accuracy: 0.6988
# pruning step: 5/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 23)        644
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 23)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 44)        9152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 44)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 44)          17468
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 44)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 176)               0
# _________________________________________________________________
# dense (Dense)                (None, 44)                7788
# _________________________________________________________________
# dropout (Dropout)            (None, 44)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                240
# =================================================================
# Total params: 36,327
# Trainable params: 36,327
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 40)        7600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 40)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 40)          14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                861
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 30,149
# Trainable params: 30,149
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.6041 - accuracy: 0.4192 - val_loss: 1.1462 - val_accuracy: 0.5979
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1333 - accuracy: 0.6140 - val_loss: 1.0088 - val_accuracy: 0.6494
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0007 - accuracy: 0.6640 - val_loss: 0.9575 - val_accuracy: 0.6718
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9279 - accuracy: 0.6885 - val_loss: 0.9234 - val_accuracy: 0.6862
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8749 - accuracy: 0.7081 - val_loss: 0.9151 - val_accuracy: 0.6920
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8427 - accuracy: 0.7167 - val_loss: 0.9179 - val_accuracy: 0.6916
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8120 - accuracy: 0.7283 - val_loss: 0.9557 - val_accuracy: 0.6849
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7853 - accuracy: 0.7387 - val_loss: 0.9217 - val_accuracy: 0.6966
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7621 - accuracy: 0.7444 - val_loss: 0.9457 - val_accuracy: 0.6928
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7514 - accuracy: 0.7513 - val_loss: 0.9568 - val_accuracy: 0.6861
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9432 - accuracy: 0.6889
# pruning step: 6/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 40)        7600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 40)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 40)          14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                861
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 30,149
# Trainable params: 30,149
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.3553 - accuracy: 0.5367 - val_loss: 1.0728 - val_accuracy: 0.6298
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0790 - accuracy: 0.6357 - val_loss: 1.0230 - val_accuracy: 0.6519
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9929 - accuracy: 0.6667 - val_loss: 0.9975 - val_accuracy: 0.6659
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9281 - accuracy: 0.6887 - val_loss: 0.9702 - val_accuracy: 0.6707
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8998 - accuracy: 0.6990 - val_loss: 0.9676 - val_accuracy: 0.6729
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8715 - accuracy: 0.7058 - val_loss: 0.9659 - val_accuracy: 0.6737
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8466 - accuracy: 0.7156 - val_loss: 0.9594 - val_accuracy: 0.6799
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8316 - accuracy: 0.7232 - val_loss: 0.9265 - val_accuracy: 0.6937
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8169 - accuracy: 0.7268 - val_loss: 0.9410 - val_accuracy: 0.6868
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7995 - accuracy: 0.7305 - val_loss: 0.9310 - val_accuracy: 0.6972
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9247 - accuracy: 0.7018
# pruning step: 7/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 18)        504
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 18)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 33)        5379
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 33)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 33)          9834
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 33)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 132)               0
# _________________________________________________________________
# dense (Dense)                (None, 33)                4389
# _________________________________________________________________
# dropout (Dropout)            (None, 33)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 18)                612
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                190
# =================================================================
# Total params: 20,908
# Trainable params: 20,908
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.4907 - accuracy: 0.4810 - val_loss: 1.1410 - val_accuracy: 0.6025
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1478 - accuracy: 0.6060 - val_loss: 1.0064 - val_accuracy: 0.6496
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0355 - accuracy: 0.6478 - val_loss: 0.9689 - val_accuracy: 0.6728
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9803 - accuracy: 0.6705 - val_loss: 0.9926 - val_accuracy: 0.6635
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9479 - accuracy: 0.6811 - val_loss: 0.9391 - val_accuracy: 0.6783
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9154 - accuracy: 0.6902 - val_loss: 0.9441 - val_accuracy: 0.6801
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8873 - accuracy: 0.6981 - val_loss: 0.9479 - val_accuracy: 0.6846
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8800 - accuracy: 0.7044 - val_loss: 0.9514 - val_accuracy: 0.6829
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8573 - accuracy: 0.7095 - val_loss: 0.9428 - val_accuracy: 0.6868
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8501 - accuracy: 0.7144 - val_loss: 0.9452 - val_accuracy: 0.6858
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9395 - accuracy: 0.6975
# pruning step: 8/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 18)        504
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 18)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 33)        5379
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 33)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 33)          9834
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 33)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 132)               0
# _________________________________________________________________
# dense (Dense)                (None, 33)                4389
# _________________________________________________________________
# dropout (Dropout)            (None, 33)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 18)                612
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                190
# =================================================================
# Total params: 20,908
# Trainable params: 20,908
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 17)        476
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 30)        4620
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 30)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 30)          8130
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 30)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 120)               0
# _________________________________________________________________
# dense (Dense)                (None, 30)                3630
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                527
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                180
# =================================================================
# Total params: 17,563
# Trainable params: 17,563
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.4401 - accuracy: 0.5090 - val_loss: 1.1303 - val_accuracy: 0.6058
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1436 - accuracy: 0.6108 - val_loss: 1.0407 - val_accuracy: 0.6419
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0734 - accuracy: 0.6395 - val_loss: 0.9937 - val_accuracy: 0.6584
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0217 - accuracy: 0.6553 - val_loss: 0.9921 - val_accuracy: 0.6597
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9815 - accuracy: 0.6662 - val_loss: 0.9736 - val_accuracy: 0.6691
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9612 - accuracy: 0.6752 - val_loss: 0.9774 - val_accuracy: 0.6683
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9258 - accuracy: 0.6864 - val_loss: 0.9686 - val_accuracy: 0.6764
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9206 - accuracy: 0.6871 - val_loss: 0.9779 - val_accuracy: 0.6716
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9107 - accuracy: 0.6955 - val_loss: 0.9566 - val_accuracy: 0.6806
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8948 - accuracy: 0.6976 - val_loss: 0.9649 - val_accuracy: 0.6775
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9739 - accuracy: 0.6822
# pruning step: 9/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 17)        476
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 30)        4620
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 30)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 30)          8130
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 30)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 120)               0
# _________________________________________________________________
# dense (Dense)                (None, 30)                3630
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                527
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                180
# =================================================================
# Total params: 17,563
# Trainable params: 17,563
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3915
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 14,512
# Trainable params: 14,512
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.6479 - accuracy: 0.4139 - val_loss: 1.3018 - val_accuracy: 0.5587
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.2828 - accuracy: 0.5523 - val_loss: 1.1157 - val_accuracy: 0.6103
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1890 - accuracy: 0.5917 - val_loss: 1.0651 - val_accuracy: 0.6322
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1119 - accuracy: 0.6209 - val_loss: 1.0492 - val_accuracy: 0.6319
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0732 - accuracy: 0.6327 - val_loss: 1.0279 - val_accuracy: 0.6408
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0472 - accuracy: 0.6435 - val_loss: 1.0183 - val_accuracy: 0.6472
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0346 - accuracy: 0.6484 - val_loss: 0.9862 - val_accuracy: 0.6592
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0161 - accuracy: 0.6561 - val_loss: 0.9870 - val_accuracy: 0.6623
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9999 - accuracy: 0.6634 - val_loss: 1.0036 - val_accuracy: 0.6580
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9809 - accuracy: 0.6685 - val_loss: 0.9964 - val_accuracy: 0.6621
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0028 - accuracy: 0.6682
# pruning step: 10/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3915
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 14,512
# Trainable params: 14,512
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 25)        3400
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 25)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 25)          5650
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 25)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 25)                2525
# _________________________________________________________________
# dropout (Dropout)            (None, 25)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                390
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 12,545
# Trainable params: 12,545
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.5198 - accuracy: 0.4612 - val_loss: 1.1912 - val_accuracy: 0.5791
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.2379 - accuracy: 0.5726 - val_loss: 1.0970 - val_accuracy: 0.6193
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1622 - accuracy: 0.6022 - val_loss: 1.0991 - val_accuracy: 0.6159
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1151 - accuracy: 0.6176 - val_loss: 1.0332 - val_accuracy: 0.6376
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0856 - accuracy: 0.6293 - val_loss: 1.0478 - val_accuracy: 0.6382
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0618 - accuracy: 0.6362 - val_loss: 1.0095 - val_accuracy: 0.6537
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0529 - accuracy: 0.6424 - val_loss: 1.0076 - val_accuracy: 0.6580
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0284 - accuracy: 0.6501 - val_loss: 0.9977 - val_accuracy: 0.6612
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0219 - accuracy: 0.6567 - val_loss: 1.0096 - val_accuracy: 0.6556
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0048 - accuracy: 0.6628 - val_loss: 1.0054 - val_accuracy: 0.6578
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0082 - accuracy: 0.6604

# %%
model_test_loss, model_test_acc = model.evaluate(test_images,  test_labels, verbose=2)
step_factor_model_test_loss, step_factor_model_test_acc = step_factor_model.evaluate(test_images,  test_labels, verbose=2)

print(f"Model accuracy before pruning: {model_test_acc*100:.2f}%")
print(f"Model accuracy after pruning: {step_factor_model_test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - loss: 0.9143 - accuracy: 0.6925
# 313/313 - 1s - loss: 1.0082 - accuracy: 0.6604
# Model accuracy before pruning: 69.25%
# Model accuracy after pruning: 66.04%

# %%
print(f"Total number of parameters before pruning: {model.count_params()}")
print(f"Total number of parameters after pruning: {step_factor_model.count_params()}")
print(f"Pruned model contains only {(step_factor_model.count_params()/model.count_params())*100:.2f}% of the original number of parameters.")
# Out:
# Total number of parameters before pruning: 75178
# Total number of parameters after pruning: 12545
# Pruned model contains only 16.69% of the original number of parameters.

# %%
step_acc_model = pruning.stepwise_accuracy_pruning(model, train_images, train_labels, test_images,
                            test_labels, pruning_acc=None, max_acc_loss=3,
                            prun_factor_dense=5, prun_factor_conv=5, 
                            metric='L1', comp=comp, label_one_hot=False)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9143 - accuracy: 0.6925
# Start model accuracy: 69.25 %
# Minimum required model accuracy: 66.25 %
# prun_factor_dense: 5 %
# prun_factor_conv: 5 %
# pruning step: 1
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 31)        868
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 31)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 61)        17080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 61)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 61)          33550
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 61)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 244)               0
# _________________________________________________________________
# dense (Dense)                (None, 61)                14945
# _________________________________________________________________
# dropout (Dropout)            (None, 61)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 31)                1922
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                320
# =================================================================
# Total params: 68,685
# Trainable params: 68,685
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.2864 - accuracy: 0.5472 - val_loss: 1.0532 - val_accuracy: 0.6375
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0113 - accuracy: 0.6562 - val_loss: 0.9586 - val_accuracy: 0.6678
# pruning step: 2
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 31)        868
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 31)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 61)        17080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 61)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 61)          33550
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 61)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 244)               0
# _________________________________________________________________
# dense (Dense)                (None, 61)                14945
# _________________________________________________________________
# dropout (Dropout)            (None, 61)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 31)                1922
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                320
# =================================================================
# Total params: 68,685
# Trainable params: 68,685
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 30)        840
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15718
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                1770
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                310
# =================================================================
# Total params: 62,486
# Trainable params: 62,486
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.0974 - accuracy: 0.6246 - val_loss: 0.9588 - val_accuracy: 0.6654
# pruning step: 3
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 30)        840
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15718
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                1770
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                310
# =================================================================
# Total params: 62,486
# Trainable params: 62,486
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 29)        812
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 29)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 56)        14672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 56)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 56)          28280
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 56)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 224)               0
# _________________________________________________________________
# dense (Dense)                (None, 56)                12600
# _________________________________________________________________
# dropout (Dropout)            (None, 56)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1653
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                300
# =================================================================
# Total params: 58,317
# Trainable params: 58,317
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.2599 - accuracy: 0.5580 - val_loss: 1.0195 - val_accuracy: 0.6488
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.9951 - accuracy: 0.6623 - val_loss: 0.9581 - val_accuracy: 0.6658
# pruning_factor_mean: 5.0 %
# weighted_model_params: 57799.55
# pruned_model.count_params(): 58317
# Increased pruning factors
# prun_factor_dense: 10 %
# prun_factor_conv: 10 %
# pruning step: 3
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 30)        840
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15718
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                1770
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                310
# =================================================================
# Total params: 62,486
# Trainable params: 62,486
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 53)        12932
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 53)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 53)          25334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 53)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 212)               0
# _________________________________________________________________
# dense (Dense)                (None, 53)                11289
# _________________________________________________________________
# dropout (Dropout)            (None, 53)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                1458
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                280
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.1969 - accuracy: 0.5809 - val_loss: 0.9806 - val_accuracy: 0.6626
# pruning step: 4
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 53)        12932
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 53)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 53)          25334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 53)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 212)               0
# _________________________________________________________________
# dense (Dense)                (None, 53)                11289
# _________________________________________________________________
# dropout (Dropout)            (None, 53)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                1458
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                280
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 25)        700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 25)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 48)        10848
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 48)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 48)          20784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 48)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                9264
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1225
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                260
# =================================================================
# Total params: 43,081
# Trainable params: 43,081
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.2846 - accuracy: 0.5460 - val_loss: 1.0704 - val_accuracy: 0.6299
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0483 - accuracy: 0.6437 - val_loss: 0.9449 - val_accuracy: 0.6730
# pruning step: 5
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 25)        700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 25)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 48)        10848
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 48)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 48)          20784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 48)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                9264
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1225
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                260
# =================================================================
# Total params: 43,081
# Trainable params: 43,081
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 23)        644
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 23)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 44)        9152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 44)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 44)          17468
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 44)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 176)               0
# _________________________________________________________________
# dense (Dense)                (None, 44)                7788
# _________________________________________________________________
# dropout (Dropout)            (None, 44)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                240
# =================================================================
# Total params: 36,327
# Trainable params: 36,327
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.1633 - accuracy: 0.5995 - val_loss: 0.9603 - val_accuracy: 0.6665
# pruning step: 6
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 23)        644
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 23)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 44)        9152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 44)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 44)          17468
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 44)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 176)               0
# _________________________________________________________________
# dense (Dense)                (None, 44)                7788
# _________________________________________________________________
# dropout (Dropout)            (None, 44)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                240
# =================================================================
# Total params: 36,327
# Trainable params: 36,327
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 40)        7600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 40)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 40)          14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                861
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 30,149
# Trainable params: 30,149
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.3515 - accuracy: 0.5289 - val_loss: 1.0602 - val_accuracy: 0.6365
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0907 - accuracy: 0.6299 - val_loss: 0.9399 - val_accuracy: 0.6737
# pruning step: 7
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 40)        7600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 40)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 40)          14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                861
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 30,149
# Trainable params: 30,149
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.3375 - accuracy: 0.5339 - val_loss: 1.0430 - val_accuracy: 0.6399
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1064 - accuracy: 0.6236 - val_loss: 0.9823 - val_accuracy: 0.6584
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0467 - accuracy: 0.6485 - val_loss: 0.9462 - val_accuracy: 0.6727
# pruning step: 8
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 18)        504
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 18)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 33)        5379
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 33)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 33)          9834
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 33)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 132)               0
# _________________________________________________________________
# dense (Dense)                (None, 33)                4389
# _________________________________________________________________
# dropout (Dropout)            (None, 33)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 18)                612
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                190
# =================================================================
# Total params: 20,908
# Trainable params: 20,908
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.2443 - accuracy: 0.5754 - val_loss: 1.0464 - val_accuracy: 0.6391
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0886 - accuracy: 0.6376 - val_loss: 1.0341 - val_accuracy: 0.6462
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0403 - accuracy: 0.6529 - val_loss: 0.9769 - val_accuracy: 0.6687
# pruning_factor_mean: 10.0 %
# weighted_model_params: 20864.95
# pruned_model.count_params(): 20908
# Increased pruning factors
# prun_factor_dense: 15 %
# prun_factor_conv: 15 %
# pruning step: 8
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 17)        476
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 31)        4774
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 31)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 31)          8680
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 31)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 124)               0
# _________________________________________________________________
# dense (Dense)                (None, 31)                3875
# _________________________________________________________________
# dropout (Dropout)            (None, 31)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                180
# =================================================================
# Total params: 18,529
# Trainable params: 18,529
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.3450 - accuracy: 0.5353 - val_loss: 1.0786 - val_accuracy: 0.6284
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1536 - accuracy: 0.6120 - val_loss: 1.0290 - val_accuracy: 0.6418
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0950 - accuracy: 0.6318 - val_loss: 0.9904 - val_accuracy: 0.6572
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0639 - accuracy: 0.6434 - val_loss: 0.9623 - val_accuracy: 0.6709
# pruning step: 9
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 17)        476
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 31)        4774
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 31)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 31)          8680
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 31)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 124)               0
# _________________________________________________________________
# dense (Dense)                (None, 31)                3875
# _________________________________________________________________
# dropout (Dropout)            (None, 31)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                180
# =================================================================
# Total params: 18,529
# Trainable params: 18,529
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                420
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 14,203
# Trainable params: 14,203
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.3352 - accuracy: 0.5366 - val_loss: 1.0876 - val_accuracy: 0.6240
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1697 - accuracy: 0.6024 - val_loss: 1.0230 - val_accuracy: 0.6534
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1269 - accuracy: 0.6149 - val_loss: 1.0257 - val_accuracy: 0.6518
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0972 - accuracy: 0.6287 - val_loss: 1.0159 - val_accuracy: 0.6586
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0801 - accuracy: 0.6358 - val_loss: 0.9983 - val_accuracy: 0.6668
# pruning step: 10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                420
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 14,203
# Trainable params: 14,203
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 13)        364
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 13)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 23)        2714
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 23)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 23)          4784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 23)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 92)                0
# _________________________________________________________________
# dense (Dense)                (None, 23)                2139
# _________________________________________________________________
# dropout (Dropout)            (None, 23)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                140
# =================================================================
# Total params: 10,453
# Trainable params: 10,453
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.7325 - accuracy: 0.3597 - val_loss: 1.3388 - val_accuracy: 0.5300
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4031 - accuracy: 0.4955 - val_loss: 1.1818 - val_accuracy: 0.5886
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3071 - accuracy: 0.5360 - val_loss: 1.1256 - val_accuracy: 0.6141
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2583 - accuracy: 0.5552 - val_loss: 1.1209 - val_accuracy: 0.6136
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2240 - accuracy: 0.5687 - val_loss: 1.0922 - val_accuracy: 0.6178
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1961 - accuracy: 0.5850 - val_loss: 1.0661 - val_accuracy: 0.6375
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1854 - accuracy: 0.5880 - val_loss: 1.0654 - val_accuracy: 0.6329
# Epoch 8/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1734 - accuracy: 0.5921 - val_loss: 1.0577 - val_accuracy: 0.6449
# Epoch 9/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1603 - accuracy: 0.5975 - val_loss: 1.0453 - val_accuracy: 0.6411
# Epoch 10/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1415 - accuracy: 0.6055 - val_loss: 1.0244 - val_accuracy: 0.6548

# %%
step_acc_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                420
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 14,203
# Trainable params: 14,203
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_test_loss, model_test_acc = model.evaluate(test_images,  test_labels, verbose=2)
step_acc_model_test_loss, step_acc_model_test_acc = step_acc_model.evaluate(test_images,  test_labels, verbose=2)

print(f"Model accuracy before pruning: {model_test_acc*100:.2f}%")
print(f"Model accuracy after pruning: {step_acc_model_test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - loss: 0.9143 - accuracy: 0.6925
# 313/313 - 1s - loss: 0.9983 - accuracy: 0.6668
# Model accuracy before pruning: 69.25%
# Model accuracy after pruning: 66.68%

# %%
print(f"Total number of parameters before pruning: {model.count_params()}")
print(f"Total number of parameters after pruning: {step_acc_model.count_params()}")
print(f"Pruned model contains only {(step_acc_model.count_params()/model.count_params())*100:.2f}% of the original number of parameters.")
# Out:
# Total number of parameters before pruning: 75178
# Total number of parameters after pruning: 14203
# Pruned model contains only 18.89% of the original number of parameters.
