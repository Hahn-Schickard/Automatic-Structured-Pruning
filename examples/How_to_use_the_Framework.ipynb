# %% [markdown]
# # Pruning with our Automatic Structured Pruning framework
# Welcome to an end-to-end example for automatic structured weight pruning
#
# **Summary**
#
# In this tutorial, you will:
#
# * Train a tf.keras model for CIFAR10 from scratch.
# * Fine tune the model by applying the different methods of the pruning Framework and see the accuracy.

# %% [markdown]
# If you want to execute this notebook in Google Colab, uncomment the code below.

# %%
import sys

if 'google.colab' in sys.modules:
    # !git clone https://github.com/Hahn-Schickard/Automatic-Structured-Pruning
    # !echo $CWD
    sys.path.append("Automatic-Structured-Pruning/src")
else:
    sys.path.append("../src")
    
import pruning

# %%
import asp as pruning

# %%
pruning.load_model_param(model)
# Out:
# (array(['Conv2D', 'MaxPooling2D', 'Conv2D', 'MaxPooling2D', 'Conv2D',
#         'MaxPooling2D', 'Flatten', 'Dense', 'Dropout', 'Dense', 'Dropout',
#         'Dense'], dtype='<U12'),
#  array([list([array([[[[-6.52834401e-02, -3.56518440e-02, -7.95705840e-02,
#             3.38718705e-02,  8.85325447e-02,  5.46130128e-02,
#             2.77920328e-02, -1.12264410e-01, -1.01500168e-01,
#            -6.32410794e-02,  7.42117837e-02, -1.39368460e-01,
#             9.42386314e-02, -1.47341162e-01, -6.25845417e-02,
#            -8.19835663e-02, -1.31177917e-01,  5.23018930e-03,
#            -7.08303526e-02, -1.15423594e-02, -8.97122249e-02,
#             4.59017865e-02, -5.51356934e-02,  2.55234614e-02,
#            -1.17180474e-01, -1.21207207e-01, -1.15345851e-01,
#            -3.34145129e-02,  1.33200079e-01, -6.27124682e-02,
#             4.92826328e-02,  1.61471859e-01],
#           [-5.98537996e-02, -5.83897941e-02, -2.94794887e-02,
#            -9.23425555e-02,  5.35296425e-02, -1.00822181e-01,
#            -6.34120405e-02, -1.18684314e-01,  1.73861850e-02,
#            -1.15064718e-01, -7.89167359e-03,  1.05700687e-01,
#            -3.55532691e-02, -6.97803050e-02, -4.02366407e-02,
#            -3.31708416e-02,  6.51238039e-02, -8.55062902e-02,
#             9.01209265e-02, -1.46171600e-01,  4.60260548e-02,
#             1.25039369e-01,  6.43556714e-02,  7.85686746e-02,
#            -3.58627252e-02, -1.26042873e-01,  7.24796671e-03,
#             1.69587582e-02, -7.16188177e-02,  2.88571082e-02,
#             9.01514217e-02, -1.36559948e-01],
#           [ 8.07370842e-02, -2.46871393e-02, -8.80867615e-02,
#             1.48347497e-01, -6.03536293e-02,  4.30651382e-02,
#            -8.25312082e-03,  1.32240579e-01, -4.24697772e-02,
#             1.74837536e-03,  4.23130617e-02,  4.72764447e-02,
#             1.02410801e-01,  1.08025476e-01,  3.80207226e-02,
#            -9.57578793e-02,  1.00549407e-01,  1.62277371e-02,
#            -1.35683179e-01,  4.05665673e-02, -9.09842625e-02,
#             8.76642019e-02,  1.50461331e-01,  1.43722817e-02,
#            -2.04849020e-02,  8.49219635e-02, -7.10116886e-03,
#            -1.44126013e-01,  1.28586903e-01,  7.25456234e-03,
#            -1.90432183e-02, -1.32249475e-01]],
#
#          [[ 1.79800496e-01, -5.06548174e-02, -7.56978523e-03,
#           3.29357624e-01, -1.00659803e-01,  2.17150867e-01,
#           4.18029875e-01, -3.72449338e-01, -1.75921526e-02,
#          -3.49495471e-01],
#         [-1.03586130e-02, -3.50984246e-01,  7.94597939e-02,
#           1.43001378e-01,  2.33924851e-01,  1.02430828e-01,
#           3.02055627e-01, -7.78332949e-02, -4.62637693e-01,
#          -2.11235657e-01],
#         [-2.07222253e-02, -1.61834657e-01,  1.00374922e-01,
#          -1.13156438e-01, -3.50578189e-01,  2.01156080e-01,
#          -6.65928572e-02,  2.46788546e-01,  2.25294679e-01,
#          -9.08334777e-02],
#         [ 1.43792466e-04, -5.54074682e-02, -2.58451194e-01,
#           3.83217275e-01, -3.08949649e-01,  4.24367875e-01,
#          -1.00922445e-02,  3.42176944e-01, -1.16127484e-01,
#          -1.44470766e-01],
#         [-4.07915920e-01,  3.46680954e-02, -2.28488892e-01,
#           1.98659360e-01, -2.33470216e-01,  2.07241587e-02,
#          -3.13725740e-01, -5.77110574e-02, -2.98590004e-01,
#          -5.74188353e-03],
#         [ 2.19771221e-01,  3.87531184e-02, -2.93233961e-01,
#           1.79635048e-01,  3.06142848e-02,  3.35468352e-01,
#           5.56618348e-03, -2.97221839e-01,  3.33665580e-01,
#           2.92594032e-03],
#         [ 2.35828757e-01,  2.77342469e-01, -4.43485612e-03,
#          -1.81258842e-01, -1.52056232e-01,  1.67979077e-01,
#           1.39751554e-01,  2.19941035e-01, -2.40995988e-01,
#           1.33963004e-01],
#         [ 3.78447622e-01,  1.28114358e-01,  2.87891269e-01,
#           1.82770818e-01, -3.80055666e-01,  1.49130166e-01,
#           5.78391319e-03,  1.45866126e-01,  1.10448420e-01,
#           2.88259178e-01],
#         [-1.28319502e-01, -4.94050890e-01,  2.90085912e-01,
#          -2.19971552e-01,  2.15928718e-01, -1.50977954e-01,
#          -9.60485935e-02,  4.03825134e-01, -4.00281221e-01,
#          -8.90729055e-02],
#         [-4.74441387e-02, -5.01769602e-01, -1.22783422e-01,
#           4.45831046e-02,  1.50499150e-01, -1.34112477e-01,
#           1.71835408e-01, -3.76184255e-01,  1.44732401e-01,
#          -3.35676014e-01]], dtype=float32), array([-0.04401556, -0.03790154,  0.01216853, -0.01045208,  0.0033627 ,
#         -0.01840477,  0.03359823,  0.04276256, -0.03644862,  0.0501979 ],
#        dtype=float32)])], dtype=object),
#  [[None, 30, 30, 32],
#   [None, 15, 15, 32],
#   [None, 13, 13, 64],
#   [None, 6, 6, 64],
#   [None, 4, 4, 64],
#   [None, 2, 2, 64],
#   [None, 256],
#   [None, 64],
#   [None, 64],
#   [None, 32],
#   [None, 32],
#   [None, 10]],
#  [True, None, True, None, True, None, None, True, None, True, None, True],
#  [NetStructure(parents=[], children=[1]),
#   NetStructure(parents=[0], children=[2]),
#   NetStructure(parents=[1], children=[3]),
#   NetStructure(parents=[2], children=[4]),
#   NetStructure(parents=[3], children=[5]),
#   NetStructure(parents=[4], children=[6]),
#   NetStructure(parents=[5], children=[7]),
#   NetStructure(parents=[6], children=[8]),
#   NetStructure(parents=[7], children=[9]),
#   NetStructure(parents=[8], children=[10]),
#   NetStructure(parents=[9], children=[11]),
#   NetStructure(parents=[10], children=[])])

# %% [markdown]
# ## Train a model for CIFAR10 without pruning
# Download and prepare the CIFAR10 dataset.
# The CIFAR10 dataset contains 60,000 color images in 10 classes, with 6,000 images in each class. The dataset is divided into 50,000 training images and 10,000 testing images. The classes are mutually exclusive and there is no overlap between them.
#
# Create the convolutional base
# The 6 lines of code below define the convolutional base using a common pattern: a stack of Conv2D and MaxPooling2D layers.
#
# As input, a CNN takes tensors of shape (image_height, image_width, color_channels), ignoring the batch size. If you are new to these dimensions, color_channels refers to (R,G,B). In this example, you will configure our CNN to process inputs of shape (32, 32, 3), which is the format of CIFAR images. You can do this by passing the argument input_shape to our first layer.
#
# To complete our model, you will feed the last output tensor from the convolutional base (of shape (4, 4, 64)) into one or more Dense layers to perform classification. Dense layers take vectors as input (which are 1D), while the current output is a 3D tensor. First, you will flatten (or unroll) the 3D output to 1D, then add one or more Dense layers on top. CIFAR has 10 output classes, so you use a final Dense layer with 10 outputs and a softmax activation.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models


(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Above, you can see that the output of every Conv2D and MaxPooling2D layer is a 3D tensor of shape (height, width, channels). The width and height dimensions tend to shrink as you go deeper in the network. The number of output channels for each Conv2D layer is controlled by the first argument (e.g., 32 or 64). Typically, as the width and height shrink, you can afford (computationally) to add more output channels in each Conv2D layer.
# As you can see, our (4, 4, 64) outputs were flattened into vectors of shape (1024) before going through two Dense layers.

# %% [markdown]
# ## Compile and train the model

# %%
comp = {
"optimizer":'adam',
"loss": tf.keras.losses.SparseCategoricalCrossentropy(),
"metrics": ['accuracy']
}

model.compile(**comp)
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]

model.fit(train_images, train_labels, validation_split=0.2, epochs=1, batch_size=128, callbacks=callbacks)

model_test_loss, model_test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f"Model accuracy after Training: {model_test_acc*100:.2f}%")
# Out:
# 313/313 [==============================] - 7s 8ms/step - loss: 2.0090 - accuracy: 0.2347 - val_loss: 1.6266 - val_accuracy: 0.4130
# 313/313 - 1s - loss: 1.6240 - accuracy: 0.4134
# Model accuracy after Training: 41.34%

# %% [markdown]
# # Prune a model
# You will apply pruning to the whole model and see this in the model summary. In this example, you prune the model with 50% dense pruning and 40% filter pruning. Therefore, the `factor_pruning` method of the framework is called.

# %%
import asp as pruning

# %%
dir(pruning)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'accuracy_pruning',
#  'build_pruned_model',
#  'factor_pruning',
#  'get_last_layer_with_params',
#  'load_model_param',
#  'model_pruning',
#  'pruning',
#  'pruning_helper_classes',
#  'pruning_helper_functions',
#  'pruning_helper_functions_conv',
#  'pruning_helper_functions_dense',
#  'stepwise_accuracy_pruning',
#  'stepwise_factor_pruning']

# %%
dense_prune_rate=50
conv_prune_rate=40
pruned_model=pruning.factor_pruning(model, dense_prune_rate, conv_prune_rate,'L1')
# Out:
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 20)        560
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 20)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 39)        7059
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 39)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 39)          13728
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 39)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 156)               0
# _________________________________________________________________
# dense (Dense)                (None, 39)                6123
# _________________________________________________________________
# dropout (Dropout)            (None, 39)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# =================================================================
# Total params: 28,480
# Trainable params: 28,480
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# C:\Users\dk100\Anaconda3\envs\asp_2\lib\site-packages\asp\pruning_helper_functions.py:108: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(layer_types), np.array(layer_params), \

# %% [markdown]
# We see how we get less parameter in the pruned model.

# %% [markdown]
# ## Compile and re-train the model

# %%
pruned_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 20)        560
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 20)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 39)        7059
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 39)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 39)          13728
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 39)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 156)               0
# _________________________________________________________________
# dense (Dense)                (None, 39)                6123
# _________________________________________________________________
# dropout (Dropout)            (None, 39)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# =================================================================
# Total params: 28,480
# Trainable params: 28,480
# Non-trainable params: 0
# _________________________________________________________________

# %%
pruned_model.compile(**comp)

pruned_model.fit(train_images, train_labels, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.7897 - accuracy: 0.3162 - val_loss: 1.5500 - val_accuracy: 0.4394
# Epoch 2/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5788 - accuracy: 0.4155 - val_loss: 1.4069 - val_accuracy: 0.4851
# Epoch 3/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4673 - accuracy: 0.4645 - val_loss: 1.2933 - val_accuracy: 0.5295
# Epoch 4/10
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.3853 - accuracy: 0.4981 - val_loss: 1.2477 - val_accuracy: 0.5500
# Epoch 5/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3211 - accuracy: 0.5252 - val_loss: 1.2324 - val_accuracy: 0.5644
# Epoch 6/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2636 - accuracy: 0.5482 - val_loss: 1.1377 - val_accuracy: 0.5942
# Epoch 7/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2231 - accuracy: 0.5640 - val_loss: 1.1307 - val_accuracy: 0.6029
# Epoch 8/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1762 - accuracy: 0.5829 - val_loss: 1.1124 - val_accuracy: 0.6020
# Epoch 9/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1452 - accuracy: 0.5952 - val_loss: 1.1297 - val_accuracy: 0.6077
# Epoch 10/10
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1152 - accuracy: 0.6079 - val_loss: 1.0552 - val_accuracy: 0.6296

# %% [markdown]
# Compare both models

# %%
model_test_loss, model_test_acc = model.evaluate(test_images,  test_labels, verbose=2)
pruned_model_test_loss, pruned_model_test_acc = pruned_model.evaluate(test_images,  test_labels, verbose=2)

print(f"Model accuracy before pruning: {model_test_acc*100:.2f}%")
print(f"Model accuracy after pruning: {pruned_model_test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - loss: 1.6454 - accuracy: 0.3963
# 313/313 - 1s - loss: 1.0611 - accuracy: 0.6323
# Model accuracy before pruning: 39.63%
# Model accuracy after pruning: 63.23%

# %%
print(f"Total number of parameters before pruning: {model.count_params()}")
print(f"Total number of parameters after pruning: {pruned_model.count_params()}")
print(f"Pruned model contains only {(pruned_model.count_params()/model.count_params())*100:.2f}% of the original number of parameters.")
# Out:
# Total number of parameters before pruning: 75178
# Total number of parameters after pruning: 28480
# Pruned model contains only 37.88% of the original number of parameters.

# %% [markdown]
# # Prune a model to a maximum accuracy loss
#
# In this case, we only want to have an accuracy loss of 3%. Therefore, the `accuracy_pruning` method of the framework is called. It is started with a pruning factor (for dense and conv) of 5. The weights and filters are removed and the network is re-trained. If the minimum accuracy is reached, the pruning factor is increased and the original model is reduced with the new pruning factor. The model is then re-trained again. This is done until the minimum accuracy is no longer reached.

# %%
auto_model = pruning.accuracy_pruning(model, comp, train_images, train_labels, test_images,
                                     test_labels, pruning_acc=None, max_acc_loss=3,
                                     label_one_hot=False)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.6454 - accuracy: 0.3963
# Start model accuracy: 39.63 %
# Minimum required model accuracy: 36.63 %
# Next pruning factors: 5
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 31)        868
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 31)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 61)        17080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 61)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 61)          33550
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 61)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 244)               0
# _________________________________________________________________
# dense (Dense)                (None, 61)                14945
# _________________________________________________________________
# dropout (Dropout)            (None, 61)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 31)                1922
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                320
# =================================================================
# Total params: 68,685
# Trainable params: 68,685
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.6579 - accuracy: 0.3804 - val_loss: 1.3990 - val_accuracy: 0.4995
# Next pruning factors: 20
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 26)        728
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 26)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 52)        12220
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 52)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 52)          24388
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 52)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 208)               0
# _________________________________________________________________
# dense (Dense)                (None, 52)                10868
# _________________________________________________________________
# dropout (Dropout)            (None, 52)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 26)                1378
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 26)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                270
# =================================================================
# Total params: 49,852
# Trainable params: 49,852
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.6872 - accuracy: 0.3658 - val_loss: 1.4271 - val_accuracy: 0.4883
# Next pruning factors: 35
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 42)        7980
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 42)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 42)          15918
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 42)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 168)               0
# _________________________________________________________________
# dense (Dense)                (None, 42)                7098
# _________________________________________________________________
# dropout (Dropout)            (None, 42)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                903
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 32,707
# Trainable params: 32,707
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.7676 - accuracy: 0.3241 - val_loss: 1.5480 - val_accuracy: 0.4161
# Next pruning factors: 50
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 32)          9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 19,162
# Trainable params: 19,162
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8483 - accuracy: 0.2844 - val_loss: 1.6134 - val_accuracy: 0.3908
# Next pruning factors: 65
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 12)        336
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 12)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 23)        2507
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 23)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 23)          4784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 23)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 92)                0
# _________________________________________________________________
# dense (Dense)                (None, 23)                2139
# _________________________________________________________________
# dropout (Dropout)            (None, 23)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                288
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                130
# =================================================================
# Total params: 10,184
# Trainable params: 10,184
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9341 - accuracy: 0.2440 - val_loss: 1.6892 - val_accuracy: 0.3422
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7474 - accuracy: 0.3220 - val_loss: 1.6190 - val_accuracy: 0.3769
# Next pruning factors: 80
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 7)         196
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 7)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 13)        832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 13)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 13)          1534
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 13)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 52)                0
# _________________________________________________________________
# dense (Dense)                (None, 13)                689
# _________________________________________________________________
# dropout (Dropout)            (None, 13)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 98
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                80
# =================================================================
# Total params: 3,429
# Trainable params: 3,429
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 2.0717 - accuracy: 0.1718 - val_loss: 1.9061 - val_accuracy: 0.2141
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9518 - accuracy: 0.2010 - val_loss: 1.8674 - val_accuracy: 0.2555
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9049 - accuracy: 0.2266 - val_loss: 1.8090 - val_accuracy: 0.2703
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8678 - accuracy: 0.2401 - val_loss: 1.7543 - val_accuracy: 0.2987
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8421 - accuracy: 0.2522 - val_loss: 1.7287 - val_accuracy: 0.3191
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8284 - accuracy: 0.2608 - val_loss: 1.7125 - val_accuracy: 0.3170
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8098 - accuracy: 0.2727 - val_loss: 1.6997 - val_accuracy: 0.3312
# Epoch 8/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7939 - accuracy: 0.2836 - val_loss: 1.6862 - val_accuracy: 0.3493
# Epoch 9/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7833 - accuracy: 0.2881 - val_loss: 1.6556 - val_accuracy: 0.3670
# Next pruning factors: 82
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 6)         168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 12)        660
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 12)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 12)          1308
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 12)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 48)                0
# _________________________________________________________________
# dense (Dense)                (None, 12)                588
# _________________________________________________________________
# dropout (Dropout)            (None, 12)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 78
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                70
# =================================================================
# Total params: 2,872
# Trainable params: 2,872
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 2.0899 - accuracy: 0.1693 - val_loss: 1.9320 - val_accuracy: 0.2094
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9704 - accuracy: 0.1850 - val_loss: 1.8869 - val_accuracy: 0.2217
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9371 - accuracy: 0.2004 - val_loss: 1.8780 - val_accuracy: 0.2254
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9213 - accuracy: 0.2059 - val_loss: 1.8773 - val_accuracy: 0.2308
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9127 - accuracy: 0.2118 - val_loss: 1.8514 - val_accuracy: 0.2345
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9023 - accuracy: 0.2123 - val_loss: 1.8448 - val_accuracy: 0.2387
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8954 - accuracy: 0.2177 - val_loss: 1.8449 - val_accuracy: 0.2356
# Epoch 8/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8935 - accuracy: 0.2161 - val_loss: 1.8449 - val_accuracy: 0.2384
# Epoch 9/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8864 - accuracy: 0.2179 - val_loss: 1.8291 - val_accuracy: 0.2489
# Epoch 10/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8814 - accuracy: 0.2186 - val_loss: 1.8334 - val_accuracy: 0.2465
# Pruningfactor dense and conv: 80

# %%
auto_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 7)         196
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 7)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 13)        832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 13)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 13)          1534
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 13)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 52)                0
# _________________________________________________________________
# dense (Dense)                (None, 13)                689
# _________________________________________________________________
# dropout (Dropout)            (None, 13)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 98
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                80
# =================================================================
# Total params: 3,429
# Trainable params: 3,429
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compare both models

# %%
model_test_loss, model_test_acc = model.evaluate(test_images,  test_labels, verbose=2)
auto_model_test_loss, auto_model_test_acc = auto_model.evaluate(test_images,  test_labels, verbose=2)

print(f"Model accuracy before pruning: {model_test_acc*100:.2f}%")
print(f"Model accuracy after pruning: {auto_model_test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - loss: 1.6454 - accuracy: 0.3963
# 313/313 - 1s - loss: 1.6556 - accuracy: 0.3670
# Model accuracy before pruning: 39.63%
# Model accuracy after pruning: 36.70%

# %%
print(f"Total number of parameters before pruning: {model.count_params()}")
print(f"Total number of parameters after pruning: {auto_model.count_params()}")
print(f"Pruned model contains only {(auto_model.count_params()/model.count_params())*100:.2f}% of the original number of parameters.")
# Out:
# Total number of parameters before pruning: 75178
# Total number of parameters after pruning: 3429
# Pruned model contains only 4.56% of the original number of parameters.

# %% [markdown]
# # Prune a model stepwise
#
# The model is not to be pruned all at once but step by step. Therefore, the `stepwise_factor_pruning` method of the framework is called. The pruning factors for dense and conv layers are defined. In addition, the number of steps is defined, how often the model should be reduced. In each step, the model is first reduced and then re-trained. In this way, the model is reduced step by step.

# %%
step_factor_model = pruning.stepwise_factor_pruning(model, train_images, train_labels, test_images,
                               test_labels, prun_factor_dense=10, prun_factor_conv=10,
                               num_steps=10, comp=comp)
# Out:
# pruning step: 1/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 29)        812
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 29)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15196
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1711
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                300
# =================================================================
# Total params: 61,867
# Trainable params: 61,867
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.7006 - accuracy: 0.3603 - val_loss: 1.4389 - val_accuracy: 0.4775
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4738 - accuracy: 0.4653 - val_loss: 1.3190 - val_accuracy: 0.5277
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.3393 - accuracy: 0.5216 - val_loss: 1.1913 - val_accuracy: 0.5714
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.2511 - accuracy: 0.5571 - val_loss: 1.1202 - val_accuracy: 0.6000
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1830 - accuracy: 0.5877 - val_loss: 1.0918 - val_accuracy: 0.6063
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1258 - accuracy: 0.6101 - val_loss: 1.0928 - val_accuracy: 0.6053
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0720 - accuracy: 0.6283 - val_loss: 1.0168 - val_accuracy: 0.6407
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0283 - accuracy: 0.6448 - val_loss: 1.0899 - val_accuracy: 0.6211
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9880 - accuracy: 0.6605 - val_loss: 0.9614 - val_accuracy: 0.6639
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9584 - accuracy: 0.6719 - val_loss: 0.9701 - val_accuracy: 0.6574
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9883 - accuracy: 0.6557
# pruning step: 2/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 29)        812
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 29)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15196
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1711
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                300
# =================================================================
# Total params: 61,867
# Trainable params: 61,867
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 53)        12932
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 53)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 53)          25334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 53)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 212)               0
# _________________________________________________________________
# dense (Dense)                (None, 53)                11289
# _________________________________________________________________
# dropout (Dropout)            (None, 53)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                1458
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                280
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.3024 - accuracy: 0.5396 - val_loss: 1.1164 - val_accuracy: 0.6103
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0518 - accuracy: 0.6385 - val_loss: 0.9630 - val_accuracy: 0.6623
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9683 - accuracy: 0.6672 - val_loss: 0.9592 - val_accuracy: 0.6627
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9250 - accuracy: 0.6859 - val_loss: 0.9406 - val_accuracy: 0.6726
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8919 - accuracy: 0.6951 - val_loss: 0.9203 - val_accuracy: 0.6791
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8570 - accuracy: 0.7069 - val_loss: 0.9447 - val_accuracy: 0.6778
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8231 - accuracy: 0.7214 - val_loss: 0.8771 - val_accuracy: 0.7029
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8035 - accuracy: 0.7260 - val_loss: 0.8883 - val_accuracy: 0.6975
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7817 - accuracy: 0.7333 - val_loss: 0.8803 - val_accuracy: 0.6982
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7645 - accuracy: 0.7378 - val_loss: 0.8975 - val_accuracy: 0.6984
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9246 - accuracy: 0.6923
# pruning step: 3/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 53)        12932
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 53)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 53)          25334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 53)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 212)               0
# _________________________________________________________________
# dense (Dense)                (None, 53)                11289
# _________________________________________________________________
# dropout (Dropout)            (None, 53)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                1458
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                280
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 25)        700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 25)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 48)        10848
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 48)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 48)          20784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 48)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                9264
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1225
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                260
# =================================================================
# Total params: 43,081
# Trainable params: 43,081
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.2227 - accuracy: 0.5725 - val_loss: 1.0246 - val_accuracy: 0.6396
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9686 - accuracy: 0.6675 - val_loss: 0.9299 - val_accuracy: 0.6783
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8825 - accuracy: 0.6977 - val_loss: 0.9439 - val_accuracy: 0.6771
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8414 - accuracy: 0.7157 - val_loss: 0.9413 - val_accuracy: 0.6754
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8000 - accuracy: 0.7289 - val_loss: 0.8915 - val_accuracy: 0.6980
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7756 - accuracy: 0.7367 - val_loss: 0.8935 - val_accuracy: 0.6972
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7573 - accuracy: 0.7425 - val_loss: 0.8986 - val_accuracy: 0.7002
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7292 - accuracy: 0.7542 - val_loss: 0.9161 - val_accuracy: 0.6987
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7129 - accuracy: 0.7579 - val_loss: 0.9086 - val_accuracy: 0.7077
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6922 - accuracy: 0.7636 - val_loss: 0.9359 - val_accuracy: 0.6920
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9330 - accuracy: 0.7020
# pruning step: 4/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 25)        700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 25)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 48)        10848
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 48)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 48)          20784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 48)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                9264
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1225
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                260
# =================================================================
# Total params: 43,081
# Trainable params: 43,081
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 23)        644
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 23)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 44)        9152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 44)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 44)          17468
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 44)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 176)               0
# _________________________________________________________________
# dense (Dense)                (None, 44)                7788
# _________________________________________________________________
# dropout (Dropout)            (None, 44)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                240
# =================================================================
# Total params: 36,327
# Trainable params: 36,327
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.2808 - accuracy: 0.5545 - val_loss: 1.0267 - val_accuracy: 0.6420
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9893 - accuracy: 0.6618 - val_loss: 0.9572 - val_accuracy: 0.6676
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8994 - accuracy: 0.6956 - val_loss: 0.9041 - val_accuracy: 0.6909
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8353 - accuracy: 0.7186 - val_loss: 0.9081 - val_accuracy: 0.6937
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8021 - accuracy: 0.7316 - val_loss: 0.9008 - val_accuracy: 0.7033
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7687 - accuracy: 0.7409 - val_loss: 0.9024 - val_accuracy: 0.7004
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7404 - accuracy: 0.7509 - val_loss: 0.9195 - val_accuracy: 0.7034
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7185 - accuracy: 0.7596 - val_loss: 0.9386 - val_accuracy: 0.6949
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7029 - accuracy: 0.7637 - val_loss: 0.9400 - val_accuracy: 0.6998
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6866 - accuracy: 0.7702 - val_loss: 0.9465 - val_accuracy: 0.7041
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9805 - accuracy: 0.7015
# pruning step: 5/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 23)        644
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 23)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 44)        9152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 44)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 44)          17468
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 44)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 176)               0
# _________________________________________________________________
# dense (Dense)                (None, 44)                7788
# _________________________________________________________________
# dropout (Dropout)            (None, 44)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                240
# =================================================================
# Total params: 36,327
# Trainable params: 36,327
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 40)        7600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 40)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 40)          14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                861
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 30,149
# Trainable params: 30,149
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.3643 - accuracy: 0.5298 - val_loss: 1.0757 - val_accuracy: 0.6208
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0346 - accuracy: 0.6499 - val_loss: 1.0865 - val_accuracy: 0.6322
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9283 - accuracy: 0.6861 - val_loss: 0.9641 - val_accuracy: 0.6743
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8678 - accuracy: 0.7076 - val_loss: 0.9157 - val_accuracy: 0.6860
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8281 - accuracy: 0.7232 - val_loss: 0.9148 - val_accuracy: 0.6938
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7907 - accuracy: 0.7347 - val_loss: 0.9549 - val_accuracy: 0.6910
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7765 - accuracy: 0.7405 - val_loss: 0.9141 - val_accuracy: 0.6954
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7498 - accuracy: 0.7491 - val_loss: 0.9582 - val_accuracy: 0.6792
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7269 - accuracy: 0.7556 - val_loss: 0.9027 - val_accuracy: 0.7049
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7175 - accuracy: 0.7589 - val_loss: 0.9215 - val_accuracy: 0.7011
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9383 - accuracy: 0.6987
# pruning step: 6/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 40)        7600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 40)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 40)          14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                861
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 30,149
# Trainable params: 30,149
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 4s 5ms/step - loss: 1.1462 - accuracy: 0.6187 - val_loss: 1.0147 - val_accuracy: 0.6545
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9692 - accuracy: 0.6764 - val_loss: 1.0007 - val_accuracy: 0.6662
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9056 - accuracy: 0.6996 - val_loss: 0.9567 - val_accuracy: 0.6772
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8669 - accuracy: 0.7122 - val_loss: 0.9285 - val_accuracy: 0.6887
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8398 - accuracy: 0.7204 - val_loss: 0.9143 - val_accuracy: 0.6959
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8172 - accuracy: 0.7259 - val_loss: 0.9472 - val_accuracy: 0.6929
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8021 - accuracy: 0.7310 - val_loss: 0.9522 - val_accuracy: 0.6905
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7881 - accuracy: 0.7391 - val_loss: 0.9248 - val_accuracy: 0.7003
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7712 - accuracy: 0.7427 - val_loss: 0.9474 - val_accuracy: 0.6904
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7689 - accuracy: 0.7430 - val_loss: 0.9447 - val_accuracy: 0.6933
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9796 - accuracy: 0.6877
# pruning step: 7/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 18)        504
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 18)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 33)        5379
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 33)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 33)          9834
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 33)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 132)               0
# _________________________________________________________________
# dense (Dense)                (None, 33)                4389
# _________________________________________________________________
# dropout (Dropout)            (None, 33)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 18)                612
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                190
# =================================================================
# Total params: 20,908
# Trainable params: 20,908
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4802 - accuracy: 0.4845 - val_loss: 1.1786 - val_accuracy: 0.5843
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1493 - accuracy: 0.6036 - val_loss: 1.0478 - val_accuracy: 0.6387
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0473 - accuracy: 0.6445 - val_loss: 1.0044 - val_accuracy: 0.6552
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9929 - accuracy: 0.6631 - val_loss: 0.9717 - val_accuracy: 0.6715
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9441 - accuracy: 0.6841 - val_loss: 0.9771 - val_accuracy: 0.6724
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9156 - accuracy: 0.6914 - val_loss: 0.9513 - val_accuracy: 0.6828
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8964 - accuracy: 0.6975 - val_loss: 0.9880 - val_accuracy: 0.6674
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8818 - accuracy: 0.7046 - val_loss: 1.0309 - val_accuracy: 0.6694
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8583 - accuracy: 0.7107 - val_loss: 0.9888 - val_accuracy: 0.6756
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8434 - accuracy: 0.7153 - val_loss: 0.9565 - val_accuracy: 0.6832
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9799 - accuracy: 0.6833
# pruning step: 8/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 18)        504
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 18)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 33)        5379
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 33)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 33)          9834
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 33)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 132)               0
# _________________________________________________________________
# dense (Dense)                (None, 33)                4389
# _________________________________________________________________
# dropout (Dropout)            (None, 33)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 18)                612
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                190
# =================================================================
# Total params: 20,908
# Trainable params: 20,908
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 17)        476
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 30)        4620
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 30)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 30)          8130
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 30)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 120)               0
# _________________________________________________________________
# dense (Dense)                (None, 30)                3630
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                527
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                180
# =================================================================
# Total params: 17,563
# Trainable params: 17,563
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.2893 - accuracy: 0.5562 - val_loss: 1.0774 - val_accuracy: 0.6258
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0854 - accuracy: 0.6304 - val_loss: 1.0016 - val_accuracy: 0.6584
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0143 - accuracy: 0.6603 - val_loss: 0.9905 - val_accuracy: 0.6651
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9780 - accuracy: 0.6709 - val_loss: 0.9587 - val_accuracy: 0.6746
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9399 - accuracy: 0.6834 - val_loss: 0.9583 - val_accuracy: 0.6786
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9249 - accuracy: 0.6872 - val_loss: 0.9720 - val_accuracy: 0.6766
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9010 - accuracy: 0.6987 - val_loss: 0.9757 - val_accuracy: 0.6737
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8878 - accuracy: 0.7007 - val_loss: 0.9465 - val_accuracy: 0.6824
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8806 - accuracy: 0.7035 - val_loss: 0.9514 - val_accuracy: 0.6797
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8633 - accuracy: 0.7102 - val_loss: 0.9834 - val_accuracy: 0.6815
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9959 - accuracy: 0.6792
# pruning step: 9/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 17)        476
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 30)        4620
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 30)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 30)          8130
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 30)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 120)               0
# _________________________________________________________________
# dense (Dense)                (None, 30)                3630
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                527
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                180
# =================================================================
# Total params: 17,563
# Trainable params: 17,563
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3915
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 14,512
# Trainable params: 14,512
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.5660 - accuracy: 0.4512 - val_loss: 1.2161 - val_accuracy: 0.5804
# Epoch 2/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.2488 - accuracy: 0.5714 - val_loss: 1.0822 - val_accuracy: 0.6299
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1424 - accuracy: 0.6146 - val_loss: 1.0400 - val_accuracy: 0.6461
# Epoch 4/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0964 - accuracy: 0.6306 - val_loss: 1.0098 - val_accuracy: 0.6609
# Epoch 5/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0604 - accuracy: 0.6399 - val_loss: 1.0053 - val_accuracy: 0.6604
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0230 - accuracy: 0.6551 - val_loss: 0.9946 - val_accuracy: 0.6668
# Epoch 7/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0081 - accuracy: 0.6605 - val_loss: 0.9897 - val_accuracy: 0.6688
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9850 - accuracy: 0.6697 - val_loss: 0.9740 - val_accuracy: 0.6723
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9749 - accuracy: 0.6709 - val_loss: 0.9655 - val_accuracy: 0.6739
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9645 - accuracy: 0.6754 - val_loss: 0.9632 - val_accuracy: 0.6742
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9689 - accuracy: 0.6804
# pruning step: 10/10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3915
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 14,512
# Trainable params: 14,512
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 25)        3400
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 25)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 25)          5650
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 25)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 25)                2525
# _________________________________________________________________
# dropout (Dropout)            (None, 25)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                390
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 12,545
# Trainable params: 12,545
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4717 - accuracy: 0.4967 - val_loss: 1.1660 - val_accuracy: 0.6005
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.2285 - accuracy: 0.5790 - val_loss: 1.0857 - val_accuracy: 0.6255
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1551 - accuracy: 0.6064 - val_loss: 1.0733 - val_accuracy: 0.6348
# Epoch 4/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0986 - accuracy: 0.6287 - val_loss: 1.0072 - val_accuracy: 0.6557
# Epoch 5/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0824 - accuracy: 0.6344 - val_loss: 1.0514 - val_accuracy: 0.6424
# Epoch 6/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0514 - accuracy: 0.6423 - val_loss: 1.0006 - val_accuracy: 0.6571
# Epoch 7/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0492 - accuracy: 0.6448 - val_loss: 0.9867 - val_accuracy: 0.6641
# Epoch 8/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0222 - accuracy: 0.6532 - val_loss: 1.0111 - val_accuracy: 0.6539
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0097 - accuracy: 0.6553 - val_loss: 1.0174 - val_accuracy: 0.6536
# Epoch 10/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0012 - accuracy: 0.6576 - val_loss: 0.9835 - val_accuracy: 0.6665
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0017 - accuracy: 0.6610

# %%
model_test_loss, model_test_acc = model.evaluate(test_images,  test_labels, verbose=2)
step_factor_model_test_loss, step_factor_model_test_acc = step_factor_model.evaluate(test_images,  test_labels, verbose=2)

print(f"Model accuracy before pruning: {model_test_acc*100:.2f}%")
print(f"Model accuracy after pruning: {step_factor_model_test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - loss: 1.6454 - accuracy: 0.3963
# 313/313 - 1s - loss: 1.0017 - accuracy: 0.6610
# Model accuracy before pruning: 39.63%
# Model accuracy after pruning: 66.10%

# %%
print(f"Total number of parameters before pruning: {model.count_params()}")
print(f"Total number of parameters after pruning: {step_factor_model.count_params()}")
print(f"Pruned model contains only {(step_factor_model.count_params()/model.count_params())*100:.2f}% of the original number of parameters.")
# Out:
# Total number of parameters before pruning: 75178
# Total number of parameters after pruning: 12545
# Pruned model contains only 16.69% of the original number of parameters.

# %% [markdown]
# # Prune a model stepwise to a maximum accuracy loss
#
# In this case, we again want to have only a 3% loss of accuracy. For this there is a second function called `stepwise_accuracy_pruning`. It is started with a pruning factor (for dense and conv) of 5. The weights and filters are removed and the network is re-trained. When the minimum accuracy is reached, the pruning factor is increased. In this case, the previous model is further reduced by the new pruning factor (as is also the case with `stepwise_factor_pruning`). The model is then trained again. This is done until the minimum accuracy is no longer reached.

# %%
step_acc_model = pruning.stepwise_accuracy_pruning(model, train_images, train_labels, test_images,
                            test_labels, pruning_acc=None, max_acc_loss=3,
                            prun_factor_dense=5, prun_factor_conv=5, 
                            metric='L1', comp=comp, label_one_hot=False)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.6454 - accuracy: 0.3963
# Start model accuracy: 39.63 %
# Minimum required model accuracy: 36.63 %
# prun_factor_dense: 5 %
# prun_factor_conv: 5 %
# pruning step: 1
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 31)        868
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 31)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 61)        17080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 61)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 61)          33550
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 61)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 244)               0
# _________________________________________________________________
# dense (Dense)                (None, 61)                14945
# _________________________________________________________________
# dropout (Dropout)            (None, 61)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 31)                1922
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                320
# =================================================================
# Total params: 68,685
# Trainable params: 68,685
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6582 - accuracy: 0.3794 - val_loss: 1.3929 - val_accuracy: 0.4861
# pruning step: 2
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 31)        868
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 31)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 61)        17080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 61)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 61)          33550
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 61)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 244)               0
# _________________________________________________________________
# dense (Dense)                (None, 61)                14945
# _________________________________________________________________
# dropout (Dropout)            (None, 61)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 31)                1922
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                320
# =================================================================
# Total params: 68,685
# Trainable params: 68,685
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 30)        840
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15718
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                1770
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                310
# =================================================================
# Total params: 62,486
# Trainable params: 62,486
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.4785 - accuracy: 0.4589 - val_loss: 1.2792 - val_accuracy: 0.5449
# pruning step: 3
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 30)        840
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15718
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                1770
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                310
# =================================================================
# Total params: 62,486
# Trainable params: 62,486
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 29)        812
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 29)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 56)        14672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 56)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 56)          28280
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 56)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 224)               0
# _________________________________________________________________
# dense (Dense)                (None, 56)                12600
# _________________________________________________________________
# dropout (Dropout)            (None, 56)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1653
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                300
# =================================================================
# Total params: 58,317
# Trainable params: 58,317
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 5ms/step - loss: 1.4223 - accuracy: 0.4799 - val_loss: 1.2323 - val_accuracy: 0.5555
# pruning_factor_mean: 5.0 %
# weighted_model_params: 57799.55
# pruned_model.count_params(): 58317
# Increased pruning factors
# prun_factor_dense: 10 %
# prun_factor_conv: 10 %
# pruning step: 3
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 30)        840
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 58)        15718
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 58)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 58)          30334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 58)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 232)               0
# _________________________________________________________________
# dense (Dense)                (None, 58)                13514
# _________________________________________________________________
# dropout (Dropout)            (None, 58)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                1770
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                310
# =================================================================
# Total params: 62,486
# Trainable params: 62,486
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 53)        12932
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 53)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 53)          25334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 53)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 212)               0
# _________________________________________________________________
# dense (Dense)                (None, 53)                11289
# _________________________________________________________________
# dropout (Dropout)            (None, 53)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                1458
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                280
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4175 - accuracy: 0.4851 - val_loss: 1.2131 - val_accuracy: 0.5597
# pruning step: 4
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 53)        12932
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 53)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 53)          25334
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 53)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 212)               0
# _________________________________________________________________
# dense (Dense)                (None, 53)                11289
# _________________________________________________________________
# dropout (Dropout)            (None, 53)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                1458
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                280
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 25)        700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 25)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 48)        10848
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 48)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 48)          20784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 48)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                9264
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1225
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                260
# =================================================================
# Total params: 43,081
# Trainable params: 43,081
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3998 - accuracy: 0.4966 - val_loss: 1.2097 - val_accuracy: 0.5628
# pruning step: 5
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 25)        700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 25)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 48)        10848
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 48)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 48)          20784
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 48)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                9264
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1225
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                260
# =================================================================
# Total params: 43,081
# Trainable params: 43,081
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 23)        644
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 23)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 44)        9152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 44)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 44)          17468
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 44)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 176)               0
# _________________________________________________________________
# dense (Dense)                (None, 44)                7788
# _________________________________________________________________
# dropout (Dropout)            (None, 44)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                240
# =================================================================
# Total params: 36,327
# Trainable params: 36,327
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3614 - accuracy: 0.5137 - val_loss: 1.1611 - val_accuracy: 0.5909
# pruning step: 6
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 23)        644
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 23)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 44)        9152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 44)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 44)          17468
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 44)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 176)               0
# _________________________________________________________________
# dense (Dense)                (None, 44)                7788
# _________________________________________________________________
# dropout (Dropout)            (None, 44)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                240
# =================================================================
# Total params: 36,327
# Trainable params: 36,327
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 40)        7600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 40)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 40)          14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                861
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 30,149
# Trainable params: 30,149
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.3112 - accuracy: 0.5344 - val_loss: 1.1318 - val_accuracy: 0.5945
# pruning step: 7
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 21)        588
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 21)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 40)        7600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 40)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 40)          14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                861
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                220
# =================================================================
# Total params: 30,149
# Trainable params: 30,149
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3174 - accuracy: 0.5357 - val_loss: 1.1670 - val_accuracy: 0.5889
# pruning step: 8
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 18)        504
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 18)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 33)        5379
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 33)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 33)          9834
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 33)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 132)               0
# _________________________________________________________________
# dense (Dense)                (None, 33)                4389
# _________________________________________________________________
# dropout (Dropout)            (None, 33)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 18)                612
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                190
# =================================================================
# Total params: 20,908
# Trainable params: 20,908
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3209 - accuracy: 0.5338 - val_loss: 1.1606 - val_accuracy: 0.5865
# pruning_factor_mean: 10.0 %
# weighted_model_params: 20864.95
# pruned_model.count_params(): 20908
# Increased pruning factors
# prun_factor_dense: 15 %
# prun_factor_conv: 15 %
# pruning step: 8
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 19)        532
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 19)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 36)        6192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 36)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 36)          11700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 36)                5220
# _________________________________________________________________
# dropout (Dropout)            (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                703
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                200
# =================================================================
# Total params: 24,547
# Trainable params: 24,547
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 17)        476
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 31)        4774
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 31)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 31)          8680
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 31)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 124)               0
# _________________________________________________________________
# dense (Dense)                (None, 31)                3875
# _________________________________________________________________
# dropout (Dropout)            (None, 31)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                180
# =================================================================
# Total params: 18,529
# Trainable params: 18,529
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3825 - accuracy: 0.5099 - val_loss: 1.1469 - val_accuracy: 0.5907
# pruning step: 9
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 17)        476
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 31)        4774
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 31)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 31)          8680
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 31)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 124)               0
# _________________________________________________________________
# dense (Dense)                (None, 31)                3875
# _________________________________________________________________
# dropout (Dropout)            (None, 31)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                180
# =================================================================
# Total params: 18,529
# Trainable params: 18,529
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                420
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 14,203
# Trainable params: 14,203
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4451 - accuracy: 0.4758 - val_loss: 1.2114 - val_accuracy: 0.5682
# pruning step: 10
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 15)        420
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 15)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 27)        3672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 27)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 27)          6588
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 27)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 108)               0
# _________________________________________________________________
# dense (Dense)                (None, 27)                2943
# _________________________________________________________________
# dropout (Dropout)            (None, 27)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                420
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 14,203
# Trainable params: 14,203
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 13)        364
# _________________________________________________________________
# ...
# conv2d_2 (Conv2D)            (None, 4, 4, 12)          1308
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 12)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 48)                0
# _________________________________________________________________
# dense (Dense)                (None, 12)                588
# _________________________________________________________________
# dropout (Dropout)            (None, 12)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 91
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                80
# =================================================================
# Total params: 3,031
# Trainable params: 3,031
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9220 - accuracy: 0.2596 - val_loss: 1.6944 - val_accuracy: 0.3671
# pruning_factor_mean: 40.0 %
# weighted_model_params: 2911.6000000000004
# pruned_model.count_params(): 3031
# Increased pruning factors
# prun_factor_dense: 45 %
# prun_factor_conv: 45 %
# pruning step: 12
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 11)        308
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 11)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 19)        1900
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 19)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 19)          3268
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 19)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 76)                0
# _________________________________________________________________
# dense (Dense)                (None, 19)                1463
# _________________________________________________________________
# dropout (Dropout)            (None, 19)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                220
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                120
# =================================================================
# Total params: 7,279
# Trainable params: 7,279
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 7)         196
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 7)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 11)        704
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 11)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 11)          1100
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 11)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 44)                0
# _________________________________________________________________
# dense (Dense)                (None, 11)                495
# _________________________________________________________________
# dropout (Dropout)            (None, 11)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 84
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                80
# =================================================================
# Total params: 2,659
# Trainable params: 2,659
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9035 - accuracy: 0.2696 - val_loss: 1.6485 - val_accuracy: 0.3863
# pruning_factor_mean: 45.0 %
# weighted_model_params: 2365.6749999999997
# pruned_model.count_params(): 2659
# Increased pruning factors
# prun_factor_dense: 50 %
# prun_factor_conv: 50 %
# pruning step: 12
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 11)        308
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 11)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 19)        1900
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 19)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 19)          3268
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 19)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 76)                0
# _________________________________________________________________
# dense (Dense)                (None, 19)                1463
# _________________________________________________________________
# dropout (Dropout)            (None, 19)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                220
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                120
# =================================================================
# Total params: 7,279
# Trainable params: 7,279
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 6)         168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 10)        550
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 10)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 10)          910
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 10)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 40)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                410
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 66
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                70
# =================================================================
# Total params: 2,174
# Trainable params: 2,174
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9952 - accuracy: 0.2280 - val_loss: 1.7868 - val_accuracy: 0.3243
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8858 - accuracy: 0.2651 - val_loss: 1.7284 - val_accuracy: 0.3421
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8485 - accuracy: 0.2821 - val_loss: 1.6939 - val_accuracy: 0.3616
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8180 - accuracy: 0.2919 - val_loss: 1.6749 - val_accuracy: 0.3655
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8037 - accuracy: 0.2991 - val_loss: 1.6340 - val_accuracy: 0.3762
# pruning_factor_mean: 50.0 %
# weighted_model_params: 1819.75
# pruned_model.count_params(): 2174
# Increased pruning factors
# prun_factor_dense: 55 %
# prun_factor_conv: 55 %
# pruning step: 12
# Finish with pruning
# Before pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 11)        308
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 11)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 19)        1900
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 19)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 19)          3268
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 19)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 76)                0
# _________________________________________________________________
# dense (Dense)                (None, 19)                1463
# _________________________________________________________________
# dropout (Dropout)            (None, 19)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                220
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                120
# =================================================================
# Total params: 7,279
# Trainable params: 7,279
# Non-trainable params: 0
# _________________________________________________________________
# After pruning:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 5)         140
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 5)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 9)         414
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 9)           0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 9)           738
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 9)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 36)                0
# _________________________________________________________________
# dense (Dense)                (None, 9)                 333
# _________________________________________________________________
# dropout (Dropout)            (None, 9)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 50
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                60
# =================================================================
# Total params: 1,735
# Trainable params: 1,735
# Non-trainable params: 0
# _________________________________________________________________
# Model built
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 2.0104 - accuracy: 0.2216 - val_loss: 1.8080 - val_accuracy: 0.3000
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9008 - accuracy: 0.2520 - val_loss: 1.7555 - val_accuracy: 0.3089
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8649 - accuracy: 0.2638 - val_loss: 1.7256 - val_accuracy: 0.3263
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8427 - accuracy: 0.2721 - val_loss: 1.7478 - val_accuracy: 0.3145
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8282 - accuracy: 0.2779 - val_loss: 1.6962 - val_accuracy: 0.3258
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8108 - accuracy: 0.2846 - val_loss: 1.6705 - val_accuracy: 0.3421
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8076 - accuracy: 0.2865 - val_loss: 1.6669 - val_accuracy: 0.3506
# Epoch 8/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8033 - accuracy: 0.2876 - val_loss: 1.7021 - val_accuracy: 0.3333
# Epoch 9/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7945 - accuracy: 0.2898 - val_loss: 1.7216 - val_accuracy: 0.3266
# Epoch 10/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7891 - accuracy: 0.2944 - val_loss: 1.6722 - val_accuracy: 0.3426

# %%
step_acc_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 11)        308
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 11)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 19)        1900
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 19)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 19)          3268
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 19)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 76)                0
# _________________________________________________________________
# dense (Dense)                (None, 19)                1463
# _________________________________________________________________
# dropout (Dropout)            (None, 19)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                220
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                120
# =================================================================
# Total params: 7,279
# Trainable params: 7,279
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_test_loss, model_test_acc = model.evaluate(test_images,  test_labels, verbose=2)
step_acc_model_test_loss, step_acc_model_test_acc = step_acc_model.evaluate(test_images,  test_labels, verbose=2)

print(f"Model accuracy before pruning: {model_test_acc*100:.2f}%")
print(f"Model accuracy after pruning: {step_acc_model_test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - loss: 1.6454 - accuracy: 0.3963
# 313/313 - 1s - loss: 1.3073 - accuracy: 0.5448
# Model accuracy before pruning: 39.63%
# Model accuracy after pruning: 54.48%

# %%
print(f"Total number of parameters before pruning: {model.count_params()}")
print(f"Total number of parameters after pruning: {step_acc_model.count_params()}")
print(f"Pruned model contains only {(step_acc_model.count_params()/model.count_params())*100:.2f}% of the original number of parameters.")
# Out:
# Total number of parameters before pruning: 75178
# Total number of parameters after pruning: 7279
# Pruned model contains only 9.68% of the original number of parameters.
